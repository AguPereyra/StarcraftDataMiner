# %% [markdown]
# # Predicting Starcraft 2 players
# [Kaggle Starcraft II Prediction Challenge](https://www.kaggle.com/c/insa-5if-2018)

# %% [markdown]
# ## Initialisation
# We will use Python3 with [Numpy](http://www.numpy.org/) for linear algebra, [Pandas](https://pandas.pydata.org/) for data processing and CSV files I/O, and [scikit-learn](https://scikit-learn.org/stable/) for predictions. The environment is defined by the [Kaggle Python docker image](https://github.com/kaggle/docker-python).

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score
from sklearn import preprocessing
from sklearn import neighbors
import os

# %% [markdown]
# ## Reading data
# Let's define some functions to read data from the CSV files. We are storing an array of actions for each line.

# %%
def read_train(file):
    ids = []
    data = []
    with open(file,'r') as f:
        for line in f:
            line_data = line.replace('\n','').split(',')
            battlenet_id, race, actions = line_data[0],line_data[1],line_data[2:]
            ids.append(battlenet_id)
            data.append([race, ", ".join([a.strip() for a in actions])])
    df = pd.DataFrame(data, columns=['race','actions'])
    series = pd.Series(ids)
    return df, series

def read_test(file):
    data = []
    with open(file,'r') as f:
        for line in f:
            line_data = line.replace('\n','').split(',')
            race, actions = line_data[0],line_data[1:]
            data.append([race, ", ".join([a.strip() for a in actions])])
    df = pd.DataFrame(data, columns=['race','actions'])
    return df

# %% [markdown]
# Input data files are available in the `../input/` directory.
# Any results written to the current directory are saved as output.

# %%
folder = '../'
train_data, train_ids = read_train(folder + 'TRAIN.CSV')
train_data.head()
# Out:
#       race                                            actions
# 0  Protoss  Base, s, s, s, s, s, t5, Base, s, hotkey30, ho...
# 1  Protoss  s, Base, s, s, Base, s, s, Base, s, t5, hotkey...
# 2  Protoss  Base, s, s, s, Base, s, hotkey30, hotkey00, t5...
# 3  Protoss  Base, s, s, Base, s, s, s, t5, Base, s, hotkey...
# 4  Protoss  Base, s, s, s, Base, s, hotkey30, hotkey00, t5...

# %%
test_data = read_test(folder + 'TEST.CSV')
test_data.head()
# Out:
#       race                                            actions
# 0     Zerg  s, s, s, hotkey10, s, hotkey60, s, hotkey00, s...
# 1   Terran  s, hotkey30, hotkey00, t5, s, hotkey32, s, hot...
# 2  Protoss  Base, s, s, Base, s, hotkey20, hotkey30, hotke...
# 3     Zerg  s, s, s, s, hotkey20, s, hotkey40, t5, t10, ho...
# 4  Protoss  Base, s, s, Base, s, hotkey50, hotkey30, t5, h...

# %% [markdown]
# ### List of actions (hotkeys)

# %%
def find_unique_actions(df):
    unique_actions = set()
    actions = df['actions']
    for action in actions:
        for a in action.split(','):
            a = a.strip()
            if a!='' and a[0]!='t':
                unique_actions.add(a)
    return unique_actions

unique_hotkeys = sorted(list(find_unique_actions(train_data)))
print(unique_hotkeys)

keys = list(set([hotkey[:len(hotkey)-1] for hotkey in unique_hotkeys if 'hotkey' in hotkey]))
print(keys)
# Out:
# ['Base', 'SingleMineral', 'hotkey00', 'hotkey01', 'hotkey02', 'hotkey10', 'hotkey11', 'hotkey12', 'hotkey20', 'hotkey21', 'hotkey22', 'hotkey30', 'hotkey31', 'hotkey32', 'hotkey40', 'hotkey41', 'hotkey42', 'hotkey50', 'hotkey51', 'hotkey52', 'hotkey60', 'hotkey61', 'hotkey62', 'hotkey70', 'hotkey71', 'hotkey72', 'hotkey80', 'hotkey81', 'hotkey82', 'hotkey90', 'hotkey91', 'hotkey92', 's']
# ['hotkey0', 'hotkey2', 'hotkey8', 'hotkey5', 'hotkey7', 'hotkey9', 'hotkey4', 'hotkey3', 'hotkey1', 'hotkey6']

# %% [markdown]
# ## Defining features
# We are defining features as the race and the number of clicks on the hotkeys in the first 10 seconds. We have
# Let's try this approach by writing a function to generate those features.
#
# We use Dummy variables to convert the race string into integers values.

# %%
hotkey_columns = ['first_hotkey','second_hotkey','third_hotkey','fourth_hotkey','fifth_hotkey','sixth_hotkey','seventh_hotkey','eighth_hotkey']

le = preprocessing.LabelEncoder()



def generate_features(df):
    features = []
    hotkeys = unique_hotkeys
    set_hotkeys = set(hotkeys)
    for index, row in df.iterrows():
        first_hotkeys = []
        race = row["race"]
        actions = row["actions"]
        hotkeys_count = {hotkey:0 for hotkey in hotkeys}
        hotkeys_count_t30 = {hotkey:0 for hotkey in hotkeys}
        hotkeys_count_t60 = {hotkey:0 for hotkey in hotkeys}
        hotkeys_count_t90 = {hotkey:0 for hotkey in hotkeys}
        hotkeys_count_t120 = {hotkey:0 for hotkey in hotkeys}
        hotkeys_count_t150 = {hotkey:0 for hotkey in hotkeys}
        hotkeys_count_t180 = {hotkey:0 for hotkey in hotkeys}
        hotkeys_count_t210 = {hotkey:0 for hotkey in hotkeys}
        t30 = False
        t60 = False
        t90 = False
        t120 = False
        t150 = False
        t180 = False
        t210 = False
        keys_count = {key:0 for key in keys}
        for action in actions.split(','):
            action = action.strip()
            if action in set_hotkeys:
                hotkeys_count[action]+=1
                if not t30:
                    hotkeys_count_t30[action]+=1
                if not t60:
                    hotkeys_count_t60[action]+=1
                if not t90:
                    hotkeys_count_t90[action]+=1
                if not t120:
                    hotkeys_count_t120[action]+=1
                if not t150:
                    hotkeys_count_t150[action]+=1
                if not t180:
                    hotkeys_count_t180[action]+=1
                if not t180:
                    hotkeys_count_t210[action]+=1
            if 'hotkey' in action:
                keys_count[action[:len(action)-1]]+=1
            if len(first_hotkeys)<len(hotkey_columns) and 'hotkey' in action:
                first_hotkeys.append(action)
                
            if 't30' in action:
                t30 = False
            elif 't60' in action:
                t60 = True
            elif 't90' in action:
                t90 = True
            elif 't120' in action:
                t120 = True
            elif 't150' in action:
                t150 = True
            elif 't180' in action:
                t180 = True
            elif 't180' in action:
                t210 = True
                
        while len(first_hotkeys)<len(hotkey_columns):
            first_hotkeys.append('None')
        current = [race, *[hotkeys_count[hotkey] for hotkey in hotkeys],*[hotkeys_count_t30[hotkey] for hotkey in hotkeys],*[hotkeys_count_t60[hotkey] for hotkey in hotkeys],*[hotkeys_count_t90[hotkey] for hotkey in hotkeys], *[hotkeys_count_t120[hotkey] for hotkey in hotkeys],*[hotkeys_count_t150[hotkey] for hotkey in hotkeys],*[hotkeys_count_t180[hotkey] for hotkey in hotkeys],*[hotkeys_count_t210[hotkey] for hotkey in hotkeys], *[keys_count[key] for key in keys], *first_hotkeys]
        features.append(current)
    new_df = pd.DataFrame(features, columns=['race', *hotkeys,*[hotkey+'_t30' for hotkey in hotkeys],*[hotkey+'_t60' for hotkey in hotkeys],*[hotkey+'_t90' for hotkey in hotkeys],*[hotkey+'_t120' for hotkey in hotkeys],*[hotkey+'_t150' for hotkey in hotkeys],*[hotkey+'_t180' for hotkey in hotkeys],*[hotkey+'_t210' for hotkey in hotkeys], *keys, *hotkey_columns])
    return new_df

# %%
train_features = generate_features(train_data)
for col in hotkey_columns:
    train_features[col] = le.fit_transform(train_features[col]) 
train_features.columns.values
# Out:
# array(['race', 'Base', 'SingleMineral', 'hotkey00', 'hotkey01',
#        'hotkey02', 'hotkey10', 'hotkey11', 'hotkey12', 'hotkey20',
#        'hotkey21', 'hotkey22', 'hotkey30', 'hotkey31', 'hotkey32',
#        'hotkey40', 'hotkey41', 'hotkey42', 'hotkey50', 'hotkey51',
#        'hotkey52', 'hotkey60', 'hotkey61', 'hotkey62', 'hotkey70',
#        'hotkey71', 'hotkey72', 'hotkey80', 'hotkey81', 'hotkey82',
#        'hotkey90', 'hotkey91', 'hotkey92', 's', 'Base_t30',
#        'SingleMineral_t30', 'hotkey00_t30', 'hotkey01_t30',
#        'hotkey02_t30', 'hotkey10_t30', 'hotkey11_t30', 'hotkey12_t30',
#        'hotkey20_t30', 'hotkey21_t30', 'hotkey22_t30', 'hotkey30_t30',
#        'hotkey31_t30', 'hotkey32_t30', 'hotkey40_t30', 'hotkey41_t30',
#        'hotkey42_t30', 'hotkey50_t30', 'hotkey51_t30', 'hotkey52_t30',
#        'hotkey60_t30', 'hotkey61_t30', 'hotkey62_t30', 'hotkey70_t30',
#        'hotkey71_t30', 'hotkey72_t30', 'hotkey80_t30', 'hotkey81_t30',
#        'hotkey82_t30', 'hotkey90_t30', 'hotkey91_t30', 'hotkey92_t30',
#        's_t30', 'Base_t60', 'SingleMineral_t60', 'hotkey00_t60',
#        'hotkey01_t60', 'hotkey02_t60', 'hotkey10_t60', 'hotkey11_t60',
#        'hotkey12_t60', 'hotkey20_t60', 'hotkey21_t60', 'hotkey22_t60',
#        'hotkey30_t60', 'hotkey31_t60', 'hotkey32_t60', 'hotkey40_t60',
#        'hotkey41_t60', 'hotkey42_t60', 'hotkey50_t60', 'hotkey51_t60',
#        'hotkey52_t60', 'hotkey60_t60', 'hotkey61_t60', 'hotkey62_t60',
#        'hotkey70_t60', 'hotkey71_t60', 'hotkey72_t60', 'hotkey80_t60',
#        'hotkey81_t60', 'hotkey82_t60', 'hotkey90_t60', 'hotkey91_t60',
#        'hotkey92_t60', 's_t60', 'Base_t90', 'SingleMineral_t90',
#        'hotkey00_t90', 'hotkey01_t90', 'hotkey02_t90', 'hotkey10_t90',
#        'hotkey11_t90', 'hotkey12_t90', 'hotkey20_t90', 'hotkey21_t90',
#        'hotkey22_t90', 'hotkey30_t90', 'hotkey31_t90', 'hotkey32_t90',
#        'hotkey40_t90', 'hotkey41_t90', 'hotkey42_t90', 'hotkey50_t90',
#        'hotkey51_t90', 'hotkey52_t90', 'hotkey60_t90', 'hotkey61_t90',
#        'hotkey62_t90', 'hotkey70_t90', 'hotkey71_t90', 'hotkey72_t90',
#        'hotkey80_t90', 'hotkey81_t90', 'hotkey82_t90', 'hotkey90_t90',
#        'hotkey91_t90', 'hotkey92_t90', 's_t90', 'Base_t120',
#        'SingleMineral_t120', 'hotkey00_t120', 'hotkey01_t120',
#        'hotkey02_t120', 'hotkey10_t120', 'hotkey11_t120', 'hotkey12_t120',
#        'hotkey20_t120', 'hotkey21_t120', 'hotkey22_t120', 'hotkey30_t120',
#        'hotkey31_t120', 'hotkey32_t120', 'hotkey40_t120', 'hotkey41_t120',
#        'hotkey42_t120', 'hotkey50_t120', 'hotkey51_t120', 'hotkey52_t120',
#        'hotkey60_t120', 'hotkey61_t120', 'hotkey62_t120', 'hotkey70_t120',
#        'hotkey71_t120', 'hotkey72_t120', 'hotkey80_t120', 'hotkey81_t120',
#        'hotkey82_t120', 'hotkey90_t120', 'hotkey91_t120', 'hotkey92_t120',
#        's_t120', 'Base_t150', 'SingleMineral_t150', 'hotkey00_t150',
#        'hotkey01_t150', 'hotkey02_t150', 'hotkey10_t150', 'hotkey11_t150',
#        'hotkey12_t150', 'hotkey20_t150', 'hotkey21_t150', 'hotkey22_t150',
#        'hotkey30_t150', 'hotkey31_t150', 'hotkey32_t150', 'hotkey40_t150',
#        'hotkey41_t150', 'hotkey42_t150', 'hotkey50_t150', 'hotkey51_t150',
#        'hotkey52_t150', 'hotkey60_t150', 'hotkey61_t150', 'hotkey62_t150',
#        'hotkey70_t150', 'hotkey71_t150', 'hotkey72_t150', 'hotkey80_t150',
#        'hotkey81_t150', 'hotkey82_t150', 'hotkey90_t150', 'hotkey91_t150',
#        'hotkey92_t150', 's_t150', 'Base_t180', 'SingleMineral_t180',
#        'hotkey00_t180', 'hotkey01_t180', 'hotkey02_t180', 'hotkey10_t180',
#        'hotkey11_t180', 'hotkey12_t180', 'hotkey20_t180', 'hotkey21_t180',
#        'hotkey22_t180', 'hotkey30_t180', 'hotkey31_t180', 'hotkey32_t180',
#        'hotkey40_t180', 'hotkey41_t180', 'hotkey42_t180', 'hotkey50_t180',
#        'hotkey51_t180', 'hotkey52_t180', 'hotkey60_t180', 'hotkey61_t180',
#        'hotkey62_t180', 'hotkey70_t180', 'hotkey71_t180', 'hotkey72_t180',
#        'hotkey80_t180', 'hotkey81_t180', 'hotkey82_t180', 'hotkey90_t180',
#        'hotkey91_t180', 'hotkey92_t180', 's_t180', 'Base_t210',
#        'SingleMineral_t210', 'hotkey00_t210', 'hotkey01_t210',
#        'hotkey02_t210', 'hotkey10_t210', 'hotkey11_t210', 'hotkey12_t210',
#        'hotkey20_t210', 'hotkey21_t210', 'hotkey22_t210', 'hotkey30_t210',
#        'hotkey31_t210', 'hotkey32_t210', 'hotkey40_t210', 'hotkey41_t210',
#        'hotkey42_t210', 'hotkey50_t210', 'hotkey51_t210', 'hotkey52_t210',
#        'hotkey60_t210', 'hotkey61_t210', 'hotkey62_t210', 'hotkey70_t210',
#        'hotkey71_t210', 'hotkey72_t210', 'hotkey80_t210', 'hotkey81_t210',
#        'hotkey82_t210', 'hotkey90_t210', 'hotkey91_t210', 'hotkey92_t210',
#        's_t210', 'hotkey0', 'hotkey2', 'hotkey8', 'hotkey5', 'hotkey7',
#        'hotkey9', 'hotkey4', 'hotkey3', 'hotkey1', 'hotkey6',
#        'first_hotkey', 'second_hotkey', 'third_hotkey', 'fourth_hotkey',
#        'fifth_hotkey', 'sixth_hotkey', 'seventh_hotkey', 'eighth_hotkey'],
#       dtype=object)

# %%
train_features = pd.get_dummies(train_features, columns = ['race']) # convert race to integers
for col in hotkey_columns:
    train_features[col] = le.fit_transform(train_features[col]) 
train_features.head()
# Out:
#    Base  SingleMineral  hotkey00  hotkey01  hotkey02  hotkey10  hotkey11  \
# 0    66              5         5         0        41        63         0
# 1    12              0         2         0        83        65         3
# 2    47              3         3         0        18        17         0
# 3    21              0         2         0        39        32         1
# 4     2              0         1         0         0        10         0
#
#    hotkey12  hotkey20  hotkey21  ...  second_hotkey  third_hotkey  \
# 0       350        37         0  ...              1            10
# 1       448        15         0  ...             11            10
# 2       130         9         0  ...              1            10
# 3       259        14         0  ...             11            10
# 4        52         6         0  ...              1            10
#
#    fourth_hotkey  fifth_hotkey  sixth_hotkey  seventh_hotkey  eighth_hotkey  \
# 0              9            10            10               9              9
# 1              9            10            10               9              9
# 2              9            10            10               9              9
# 3              9            10            10               9              9
# 4              9            10            10               9              9
#
#    race_Protoss  race_Terran  race_Zerg
# 0             1            0          0
# 1             1            0          0
# 2             1            0          0
# 3             1            0          0
# 4             1            0          0
#
# [5 rows x 285 columns]

# %%
id=train_ids.to_numpy()
print(id)
# Out:
# ['http://eu.battle.net/sc2/en/profile/4234852/1/First/'
#  'http://eu.battle.net/sc2/en/profile/3074362/1/Stardust/'
#  'http://eu.battle.net/sc2/en/profile/4234852/1/First/' ...
#  'http://xx.battle.net/sc2/en/profile/405/1/MMA/'
#  'http://xx.battle.net/sc2/en/profile/410/1/STBomber/'
#  'http://xx.battle.net/sc2/en/profile/405/1/MMA/']

# %%
x_train, x_test, y_train, y_test = train_test_split(train_features, train_ids, stratify=id, test_size=0.30)

# %%
from imblearn.over_sampling import ADASYN

ada = ADASYN(sampling_strategy='minority', random_state= 420 , n_neighbors = 2)

x_train, y_train = ada.fit_resample(x_train, y_train)
# Out:
# Using TensorFlow backend.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Amélioration de 0.03 avec smote ce qui est pas mal du tout
#smt = SMOTE()
#train_freatures, train_ids = smt.fit_sample(train_features, train_ids)
ada = ADASYN(sampling_strategy='minority', random_state= 420 , n_neighbors = 2)

train_freatures, train_ids = ada.fit_resample(train_features, train_ids)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
train_freatures = scaler.fit_transform(train_freatures)

# %%
test_features = generate_features(test_data)
test_features = pd.get_dummies(test_features, columns = ['race']) # convert race to integers
for col in hotkey_columns:
    test_features[col] = le.fit_transform(test_features[col]) 

'''
# Get missing columns in the training test
missing_cols = set( train_features.columns ) - set( test_features.columns )
# Add a missing column in test set with default value equal to 0
for c in missing_cols:
    test_features[c] = 0
# Ensure the order of column in the test set is in the same order than in train set
test_features = test_features[train_features.columns]
'''

test_features.head()
# Out:
#    Base  SingleMineral  hotkey00  hotkey01  hotkey02  hotkey10  hotkey11  \
# 0    19              3        14         0       847         7        31
# 1     0              0         2         0        33        14         0
# 2    20              0         1         0         0        10         0
# 3    17              2         0         0         0        68        89
# 4    21              0         3         0         0         4         7
#
#    hotkey12  hotkey20  hotkey21  ...  second_hotkey  third_hotkey  \
# 0       352        10         0  ...             15             1
# 1       336        31         0  ...              1            10
# 2       479        53         0  ...              9            15
# 3       525        13         6  ...             11             7
# 4        74         8         0  ...              9            11
#
#    fourth_hotkey  fifth_hotkey  sixth_hotkey  seventh_hotkey  eighth_hotkey  \
# 0             21             3             2              16              3
# 1              9             9             8               9              9
# 2             10            20            16              16             16
# 3             12            11            10              11              7
# 4             14            14            12              13             14
#
#    race_Protoss  race_Terran  race_Zerg
# 0             0            0          1
# 1             0            1          0
# 2             1            0          0
# 3             0            0          1
# 4             1            0          0
#
# [5 rows x 285 columns]

# %%
scaler = StandardScaler()
test_features = scaler.fit_transform(test_features)

# %% [markdown]
# ## Predicting players

# %%
def read_csv_head(path):
    with open(path, 'r') as f:
        c = 0
        for line in f:
            print(line)
            c+=1
            if c==10:
                break

def convert(output):
    output_df = pd.DataFrame(output, columns=['prediction'])
    output_df.index = range(1,len(output_df)+1)
    output_df.index.name = 'RowId'
    return output_df

def save(output_df, name):
    output_df.to_csv('./out_'+name+'.csv')

# %% [markdown]
# ### Third approach: Random Forest

# %%
classifier = RandomForestClassifier(random_state=13 ,n_estimators=800)
classifier.fit(x_train,y_train)
y_predict = classifier.predict(x_test)
f1_score(y_test, y_predict, average='micro')
# Out:
# 0.9366812227074236

# %%
# Get numerical feature importances
feature_list=list(train_features.columns)
importances = list(classifier.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances]
# Out:
# Variable: first_hotkey         Importance: 0.02
# Variable: second_hotkey        Importance: 0.02
# Variable: Base                 Importance: 0.01
# Variable: SingleMineral        Importance: 0.01
# Variable: hotkey00             Importance: 0.01
# Variable: hotkey02             Importance: 0.01
# Variable: hotkey10             Importance: 0.01
# Variable: hotkey11             Importance: 0.01
# Variable: hotkey12             Importance: 0.01
# Variable: hotkey20             Importance: 0.01
# Variable: hotkey22             Importance: 0.01
# Variable: hotkey30             Importance: 0.01
# Variable: hotkey32             Importance: 0.01
# Variable: hotkey40             Importance: 0.01
# Variable: hotkey42             Importance: 0.01
# Variable: hotkey50             Importance: 0.01
# Variable: hotkey52             Importance: 0.01
# Variable: hotkey60             Importance: 0.01
# Variable: hotkey62             Importance: 0.01
# Variable: hotkey72             Importance: 0.01
# Variable: hotkey82             Importance: 0.01
# Variable: hotkey92             Importance: 0.01
# Variable: Base_t30             Importance: 0.01
# Variable: SingleMineral_t30    Importance: 0.01
# Variable: hotkey00_t30         Importance: 0.01
# Variable: hotkey02_t30         Importance: 0.01
# Variable: hotkey10_t30         Importance: 0.01
# Variable: hotkey11_t30         Importance: 0.01
# Variable: hotkey12_t30         Importance: 0.01
# Variable: hotkey20_t30         Importance: 0.01
# Variable: hotkey22_t30         Importance: 0.01
# Variable: hotkey30_t30         Importance: 0.01
# Variable: hotkey32_t30         Importance: 0.01
# Variable: hotkey40_t30         Importance: 0.01
# Variable: hotkey42_t30         Importance: 0.01
# Variable: hotkey50_t30         Importance: 0.01
# Variable: hotkey52_t30         Importance: 0.01
# Variable: hotkey60_t30         Importance: 0.01
# Variable: hotkey62_t30         Importance: 0.01
# Variable: hotkey72_t30         Importance: 0.01
# Variable: hotkey82_t30         Importance: 0.01
# Variable: hotkey92_t30         Importance: 0.01
# Variable: Base_t60             Importance: 0.01
# Variable: hotkey10_t60         Importance: 0.01
# Variable: hotkey12_t60         Importance: 0.01
# Variable: hotkey20_t60         Importance: 0.01
# Variable: hotkey22_t60         Importance: 0.01
# Variable: hotkey30_t60         Importance: 0.01
# Variable: hotkey32_t60         Importance: 0.01
# Variable: hotkey40_t60         Importance: 0.01
# Variable: hotkey42_t60         Importance: 0.01
# Variable: hotkey50_t60         Importance: 0.01
# Variable: hotkey52_t60         Importance: 0.01
# Variable: s_t60                Importance: 0.01
# Variable: Base_t90             Importance: 0.01
# Variable: hotkey10_t90         Importance: 0.01
# Variable: hotkey12_t90         Importance: 0.01
# Variable: hotkey20_t90         Importance: 0.01
# Variable: hotkey22_t90         Importance: 0.01
# Variable: hotkey30_t90         Importance: 0.01
# Variable: hotkey32_t90         Importance: 0.01
# Variable: hotkey40_t90         Importance: 0.01
# Variable: hotkey42_t90         Importance: 0.01
# Variable: hotkey50_t90         Importance: 0.01
# Variable: hotkey52_t90         Importance: 0.01
# Variable: s_t90                Importance: 0.01
# Variable: Base_t120            Importance: 0.01
# Variable: hotkey10_t120        Importance: 0.01
# Variable: hotkey12_t120        Importance: 0.01
# Variable: hotkey20_t120        Importance: 0.01
# Variable: hotkey22_t120        Importance: 0.01
# Variable: hotkey30_t120        Importance: 0.01
# Variable: hotkey32_t120        Importance: 0.01
# Variable: hotkey40_t120        Importance: 0.01
# Variable: hotkey42_t120        Importance: 0.01
# Variable: hotkey50_t120        Importance: 0.01
# Variable: hotkey52_t120        Importance: 0.01
# Variable: s_t120               Importance: 0.01
# Variable: hotkey0              Importance: 0.01
# Variable: hotkey6              Importance: 0.01
# Variable: hotkey8              Importance: 0.01
# Variable: hotkey1              Importance: 0.01
# Variable: hotkey9              Importance: 0.01
# Variable: hotkey4              Importance: 0.01
# Variable: hotkey2              Importance: 0.01
# Variable: hotkey3              Importance: 0.01
# Variable: hotkey5              Importance: 0.01
# Variable: hotkey7              Importance: 0.01
# Variable: third_hotkey         Importance: 0.01
# Variable: fourth_hotkey        Importance: 0.01
# Variable: fifth_hotkey         Importance: 0.01
# Variable: sixth_hotkey         Importance: 0.01
# Variable: seventh_hotkey       Importance: 0.01
# Variable: eighth_hotkey        Importance: 0.01
# Variable: race_Protoss         Importance: 0.01
# Variable: race_Zerg            Importance: 0.01
# Variable: hotkey01             Importance: 0.0
# Variable: hotkey21             Importance: 0.0
# Variable: hotkey31             Importance: 0.0
# Variable: hotkey41             Importance: 0.0
# Variable: hotkey51             Importance: 0.0
# Variable: hotkey61             Importance: 0.0
# Variable: hotkey70             Importance: 0.0
# Variable: hotkey71             Importance: 0.0
# Variable: hotkey80             Importance: 0.0
# Variable: hotkey81             Importance: 0.0
# Variable: hotkey90             Importance: 0.0
# Variable: hotkey91             Importance: 0.0
# Variable: s                    Importance: 0.0
# Variable: hotkey01_t30         Importance: 0.0
# Variable: hotkey21_t30         Importance: 0.0
# Variable: hotkey31_t30         Importance: 0.0
# Variable: hotkey41_t30         Importance: 0.0
# Variable: hotkey51_t30         Importance: 0.0
# Variable: hotkey61_t30         Importance: 0.0
# Variable: hotkey70_t30         Importance: 0.0
# Variable: hotkey71_t30         Importance: 0.0
# Variable: hotkey80_t30         Importance: 0.0
# Variable: hotkey81_t30         Importance: 0.0
# Variable: hotkey90_t30         Importance: 0.0
# Variable: hotkey91_t30         Importance: 0.0
# Variable: s_t30                Importance: 0.0
# Variable: SingleMineral_t60    Importance: 0.0
# Variable: hotkey00_t60         Importance: 0.0
# Variable: hotkey01_t60         Importance: 0.0
# Variable: hotkey02_t60         Importance: 0.0
# Variable: hotkey11_t60         Importance: 0.0
# Variable: hotkey21_t60         Importance: 0.0
# Variable: hotkey31_t60         Importance: 0.0
# Variable: hotkey41_t60         Importance: 0.0
# Variable: hotkey51_t60         Importance: 0.0
# Variable: hotkey60_t60         Importance: 0.0
# Variable: hotkey61_t60         Importance: 0.0
# Variable: hotkey62_t60         Importance: 0.0
# Variable: hotkey70_t60         Importance: 0.0
# Variable: hotkey71_t60         Importance: 0.0
# Variable: hotkey72_t60         Importance: 0.0
# Variable: hotkey80_t60         Importance: 0.0
# Variable: hotkey81_t60         Importance: 0.0
# Variable: hotkey82_t60         Importance: 0.0
# Variable: hotkey90_t60         Importance: 0.0
# Variable: hotkey91_t60         Importance: 0.0
# Variable: hotkey92_t60         Importance: 0.0
# Variable: SingleMineral_t90    Importance: 0.0
# Variable: hotkey00_t90         Importance: 0.0
# Variable: hotkey01_t90         Importance: 0.0
# Variable: hotkey02_t90         Importance: 0.0
# Variable: hotkey11_t90         Importance: 0.0
# Variable: hotkey21_t90         Importance: 0.0
# Variable: hotkey31_t90         Importance: 0.0
# Variable: hotkey41_t90         Importance: 0.0
# Variable: hotkey51_t90         Importance: 0.0
# Variable: hotkey60_t90         Importance: 0.0
# Variable: hotkey61_t90         Importance: 0.0
# Variable: hotkey62_t90         Importance: 0.0
# Variable: hotkey70_t90         Importance: 0.0
# Variable: hotkey71_t90         Importance: 0.0
# Variable: hotkey72_t90         Importance: 0.0
# Variable: hotkey80_t90         Importance: 0.0
# Variable: hotkey81_t90         Importance: 0.0
# Variable: hotkey82_t90         Importance: 0.0
# Variable: hotkey90_t90         Importance: 0.0
# Variable: hotkey91_t90         Importance: 0.0
# Variable: hotkey92_t90         Importance: 0.0
# Variable: SingleMineral_t120   Importance: 0.0
# Variable: hotkey00_t120        Importance: 0.0
# Variable: hotkey01_t120        Importance: 0.0
# Variable: hotkey02_t120        Importance: 0.0
# Variable: hotkey11_t120        Importance: 0.0
# Variable: hotkey21_t120        Importance: 0.0
# Variable: hotkey31_t120        Importance: 0.0
# Variable: hotkey41_t120        Importance: 0.0
# Variable: hotkey51_t120        Importance: 0.0
# Variable: hotkey60_t120        Importance: 0.0
# Variable: hotkey61_t120        Importance: 0.0
# Variable: hotkey62_t120        Importance: 0.0
# Variable: hotkey70_t120        Importance: 0.0
# Variable: hotkey71_t120        Importance: 0.0
# Variable: hotkey72_t120        Importance: 0.0
# Variable: hotkey80_t120        Importance: 0.0
# Variable: hotkey81_t120        Importance: 0.0
# Variable: hotkey82_t120        Importance: 0.0
# Variable: hotkey90_t120        Importance: 0.0
# Variable: hotkey91_t120        Importance: 0.0
# Variable: hotkey92_t120        Importance: 0.0
# Variable: race_Terran          Importance: 0.0
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
# list of x locations for plotting
x_values = list(range(len(importances)))
# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical', color = 'r', edgecolor = 'k', linewidth = 1.2)
# Tick labels for x axis
plt.xticks(x_values, feature_list, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
# List of features sorted from most to least important
sorted_importances = [importance[1] for importance in feature_importances]
sorted_features = [importance[0] for importance in feature_importances]
# Cumulative importances
cumulative_importances = np.cumsum(sorted_importances)
# Make a line graph
plt.plot(x_values, cumulative_importances, 'g-')
# Draw line at 95% of importance retained
plt.hlines(y = 0.95, xmin=0, xmax=len(sorted_importances), color = 'r', linestyles = 'dashed')
# Format x ticks and labels
plt.xticks(x_values, sorted_features, rotation = 'vertical')
# Axis labels and title
plt.xlabel('Variable'); plt.ylabel('Cumulative Importance'); plt.title('Cumulative Importances');

# %%
# Find number of features for cumulative importance of 95%
# Add 1 because Python is zero-indexed
print('Number of features for 95% importance:', np.where(cumulative_importances > 0.95)[0][0] + 1)
# Out:
# Number of features for 95% importance: 93

# %%
# Extract the names of the most important features
important_feature_names = [feature[0] for feature in feature_importances[0:92]]
# Find the columns of the most important features
important_indices = [feature_list.index(feature) for feature in important_feature_names]


# Sanity check on operations
print('Important train features shape:', important_indices)
# Out:
# Important train features shape: [175, 176, 0, 1, 2, 4, 5, 6, 7, 8, 10, 11, 13, 14, 16, 17, 19, 20, 22, 25, 28, 31, 33, 34, 35, 37, 38, 39, 40, 41, 43, 44, 46, 47, 49, 50, 52, 53, 55, 58, 61, 64, 66, 71, 73, 74, 76, 77, 79, 80, 82, 83, 85, 98, 99, 104, 106, 107, 109, 110, 112, 113, 115, 116, 118, 131, 132, 137, 139, 140, 142, 143, 145, 146, 148, 149, 151, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 177, 178, 179, 180]

# %%
from sklearn.metrics import multilabel_confusion_matrix
print('Confusion Matrix - Training Dataset')
multilabel_confusion_matrix(y_test, y_predict, labels=id)
# Out:
# Confusion Matrix - Training Dataset
# array([[[911,   0],
#         [  0,   5]],
#
#        [[905,   0],
#         [  0,  11]],
#
#        [[911,   0],
#         [  0,   5]],
#
#        ...,
#
#        [[915,   0],
#         [  0,   1]],
#
#        [[910,   1],
#         [  1,   4]],
#
#        [[915,   0],
#         [  0,   1]]], dtype=int64)

# %%
n_estimators=range(100,1000,100)
hyper={'n_estimators':n_estimators}
gd=GridSearchCV(estimator=RandomForestClassifier(random_state=13),param_grid=hyper,verbose=True)
gd.fit(X_train,y_train)
print(gd.best_score_)
print(gd.best_estimator_)

# %%
rf = RandomForestClassifier(random_state=13, n_estimators=800)
rf.fit(train_freatures,train_ids)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=800,
#                        n_jobs=None, oob_score=False, random_state=13, verbose=0,
#                        warm_start=False)

# %%
predicted_ids_rf = rf.predict(test_features)
predicted_ids_rf_df = convert(predicted_ids_rf)
save(predicted_ids_rf_df, 'randomforesttest') # test 1 , smote k = 2 / test 2 , smote k=3 => resultats 3 moins efficace ?
#test3 adasyn # test 4 ada de ade # ade + scaled
predicted_ids_rf_df.head()
# Out:
#                                               prediction
# RowId
# 1      http://eu.battle.net/sc2/en/profile/3538115/1/...
# 2      http://eu.battle.net/sc2/en/profile/2896854/1/...
# 3      http://eu.battle.net/sc2/en/profile/3973341/1/...
# 4      http://eu.battle.net/sc2/en/profile/250458/1/V...
# 5      http://eu.battle.net/sc2/en/profile/950504/1/G...

# %% [markdown]
# #  Fin
